# %%
# %matplotlib inline
import numpy as np
import time
import MDAnalysis as mda
from MDAnalysis.tests.datafiles import XTC, GRO
import MDAnalysis.analysis.rms
from MDAnalysis.analysis.rms import rmsd
from MDAnalysis.analysis import align
from MDAnalysis.analysis.dihedrals import Dihedral as dihedral
var_xtc = '/Volumes/3KSPAT/from_2KSPAT/metad_convergence/wt/free_ener_wt/8us/zone1.xtc'
var_gro = '/Volumes/3KSPAT/from_2KSPAT/metad_convergence/wt/free_ener_wt/8us/active_mek_wt_protein.gro' 
u = mda.Universe(var_gro, var_xtc)

selection = 'resname {} and resid {} and name {}'
ALA2N = selection.format('ASP', 208, 'CA')
ALA2CA = selection.format('ASP', 208, 'CG')
ALA2C = selection.format('CYS', 207, 'CA')
TYR3N = selection.format('CYS', 207, 'CB')
psi = [ALA2N, ALA2CA, ALA2C, TYR3N]

psi_angle = sum([u.select_atoms(atom) for atom in psi])  # sum of Atoms creates an AtomGroup
psi_angle = psi_angle.dihedral  # convert AtomGroup to Dihedral object

psi_list = []
for ts in u.trajectory:
    psi_list.append(psi_angle.value())
    
    
import matplotlib
import numpy as np
import matplotlib.pyplot as plt


psi_list = np.array(psi_list)

num_bins = 50

fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(psi_list, num_bins, density=True,color = "salmon")



#ax.plot(bins, y, '--')
ax.set_xlabel('Dihedral angle in deg',fontsize=18)
ax.set_ylabel('Frequency density',fontsize=18)
ax.set_title('DFG histogram',fontsize=18)
plt.xlim((-180,180))
plt.xticks(fontsize= 14)
#plt.yticks(fontsize= 20)
# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.savefig('DFG_z1.png', bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
# %matplotlib inline
import numpy as np
import time
import MDAnalysis as mda
from MDAnalysis.tests.datafiles import XTC, GRO
import MDAnalysis.analysis.rms
from MDAnalysis.analysis.rms import rmsd
from MDAnalysis.analysis import align
from MDAnalysis.analysis.dihedrals import Dihedral as dihedral
var_xtc = '/Volumes/3KSPAT/from_2KSPAT/metad_convergence/wt/free_ener_wt/8us/zone2.xtc'
var_gro = '/Volumes/3KSPAT/from_2KSPAT/metad_convergence/wt/free_ener_wt/8us/active_mek_wt_protein.gro' 
u = mda.Universe(var_gro, var_xtc)

selection = 'resname {} and resid {} and name {}'
ALA2N = selection.format('ASP', 208, 'CA')
ALA2CA = selection.format('ASP', 208, 'CG')
ALA2C = selection.format('CYS', 207, 'CA')
TYR3N = selection.format('CYS', 207, 'CB')
psi = [ALA2N, ALA2CA, ALA2C, TYR3N]

psi_angle = sum([u.select_atoms(atom) for atom in psi])  # sum of Atoms creates an AtomGroup
psi_angle = psi_angle.dihedral  # convert AtomGroup to Dihedral object

psi_list = []
for ts in u.trajectory:
    psi_list.append(psi_angle.value())
    
    
import matplotlib
import numpy as np
import matplotlib.pyplot as plt


psi_list = np.array(psi_list)

num_bins = 50

fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(psi_list, num_bins, density=True,color = "salmon")



#ax.plot(bins, y, '--')
ax.set_xlabel('Dihedral angle in deg',fontsize=18)
ax.set_ylabel('Frequency density',fontsize=18)
ax.set_title('DFG histogram',fontsize=18)
plt.xlim((-180,180))
plt.xticks(fontsize= 14)
#plt.yticks(fontsize= 20)
# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.savefig('DFG_z2.png', bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
# %matplotlib inline
import numpy as np
import time
import MDAnalysis as mda
from MDAnalysis.tests.datafiles import XTC, GRO
import MDAnalysis.analysis.rms
from MDAnalysis.analysis.rms import rmsd
from MDAnalysis.analysis import align
from MDAnalysis.analysis.dihedrals import Dihedral as dihedral
var_xtc = '/Volumes/3KSPAT/from_2KSPAT/metad_convergence/wt/free_ener_wt/8us/zone3.xtc'
var_gro = '/Volumes/3KSPAT/from_2KSPAT/metad_convergence/wt/free_ener_wt/8us/active_mek_wt_protein.gro' 
u = mda.Universe(var_gro, var_xtc)

selection = 'resname {} and resid {} and name {}'
ALA2N = selection.format('ASP', 208, 'CA')
ALA2CA = selection.format('ASP', 208, 'CG')
ALA2C = selection.format('CYS', 207, 'CA')
TYR3N = selection.format('CYS', 207, 'CB')
psi = [ALA2N, ALA2CA, ALA2C, TYR3N]

psi_angle = sum([u.select_atoms(atom) for atom in psi])  # sum of Atoms creates an AtomGroup
psi_angle = psi_angle.dihedral  # convert AtomGroup to Dihedral object

psi_list = []
for ts in u.trajectory:
    psi_list.append(psi_angle.value())
    
    
import matplotlib
import numpy as np
import matplotlib.pyplot as plt


psi_list = np.array(psi_list)

num_bins = 50

fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(psi_list, num_bins, density=True,color = "salmon")



#ax.plot(bins, y, '--')
ax.set_xlabel('Dihedral angle in deg',fontsize=18)
ax.set_ylabel('Frequency density',fontsize=18)
ax.set_title('DFG histogram',fontsize=18)
plt.xlim((-180,180))
plt.xticks(fontsize= 14)
#plt.yticks(fontsize= 20)
# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.savefig('DFG_z3.png', bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
# %matplotlib inline
import numpy as np
import time
import MDAnalysis as mda
from MDAnalysis.tests.datafiles import XTC, GRO
import MDAnalysis.analysis.rms
from MDAnalysis.analysis.rms import rmsd
from MDAnalysis.analysis import align
from MDAnalysis.analysis.dihedrals import Dihedral as dihedral
var_xtc = '/Volumes/3KSPAT/from_2KSPAT/metad_convergence/wt/free_ener_wt/8us/zone4.xtc'
var_gro = '/Volumes/3KSPAT/from_2KSPAT/metad_convergence/wt/free_ener_wt/8us/active_mek_wt_protein.gro' 
u = mda.Universe(var_gro, var_xtc)

selection = 'resname {} and resid {} and name {}'
ALA2N = selection.format('ASP', 208, 'CA')
ALA2CA = selection.format('ASP', 208, 'CG')
ALA2C = selection.format('CYS', 207, 'CA')
TYR3N = selection.format('CYS', 207, 'CB')
psi = [ALA2N, ALA2CA, ALA2C, TYR3N]

psi_angle = sum([u.select_atoms(atom) for atom in psi])  # sum of Atoms creates an AtomGroup
psi_angle = psi_angle.dihedral  # convert AtomGroup to Dihedral object

psi_list = []
for ts in u.trajectory:
    psi_list.append(psi_angle.value())
    
    
import matplotlib
import numpy as np
import matplotlib.pyplot as plt


psi_list = np.array(psi_list)

num_bins = 50

fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(psi_list, num_bins, density=True,color = "salmon")



#ax.plot(bins, y, '--')
ax.set_xlabel('Dihedral angle in deg',fontsize=18)
ax.set_ylabel('Frequency density',fontsize=18)
ax.set_title('DFG histogram',fontsize=18)
plt.xlim((-180,180))
plt.xticks(fontsize= 14)
#plt.yticks(fontsize= 20)
# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.savefig('DFG_z4.png', bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
# %matplotlib inline
import numpy as np
import time
import MDAnalysis as mda
from MDAnalysis.tests.datafiles import XTC, GRO
import MDAnalysis.analysis.rms
from MDAnalysis.analysis.rms import rmsd
from MDAnalysis.analysis import align
from MDAnalysis.analysis.dihedrals import Dihedral as dihedral
var_xtc = '/Volumes/3KSPAT/from_2KSPAT/metad_convergence/wt/free_ener_wt/8us/zone5.xtc'
var_gro = '/Volumes/3KSPAT/from_2KSPAT/metad_convergence/wt/free_ener_wt/8us/active_mek_wt_protein.gro' 
u = mda.Universe(var_gro, var_xtc)

selection = 'resname {} and resid {} and name {}'
ALA2N = selection.format('ASP', 208, 'CA')
ALA2CA = selection.format('ASP', 208, 'CG')
ALA2C = selection.format('CYS', 207, 'CA')
TYR3N = selection.format('CYS', 207, 'CB')
psi = [ALA2N, ALA2CA, ALA2C, TYR3N]

psi_angle = sum([u.select_atoms(atom) for atom in psi])  # sum of Atoms creates an AtomGroup
psi_angle = psi_angle.dihedral  # convert AtomGroup to Dihedral object

psi_list = []
for ts in u.trajectory:
    psi_list.append(psi_angle.value())
    
    
import matplotlib
import numpy as np
import matplotlib.pyplot as plt


psi_list = np.array(psi_list)

num_bins = 50

fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(psi_list, num_bins, density=True,color = "salmon")



#ax.plot(bins, y, '--')
ax.set_xlabel('Dihedral angle in deg',fontsize=18)
ax.set_ylabel('Frequency density',fontsize=18)
ax.set_title('DFG histogram',fontsize=18)
plt.xlim((-180,180))
plt.xticks(fontsize= 14)
#plt.yticks(fontsize= 20)
# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.savefig('DFG_z5.png', bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
# %matplotlib inline
import numpy as np
import time
import MDAnalysis as mda
from MDAnalysis.tests.datafiles import XTC, GRO
import MDAnalysis.analysis.rms
from MDAnalysis.analysis.rms import rmsd
from MDAnalysis.analysis import align
from MDAnalysis.analysis.dihedrals import Dihedral as dihedral
var_xtc = '/Volumes/3KSPAT/from_2KSPAT/metad_convergence/wt/free_ener_wt/8us/zone6.xtc'
var_gro = '/Volumes/3KSPAT/from_2KSPAT/metad_convergence/wt/free_ener_wt/8us/active_mek_wt_protein.gro' 
u = mda.Universe(var_gro, var_xtc)

selection = 'resname {} and resid {} and name {}'
ALA2N = selection.format('ASP', 208, 'CA')
ALA2CA = selection.format('ASP', 208, 'CG')
ALA2C = selection.format('CYS', 207, 'CA')
TYR3N = selection.format('CYS', 207, 'CB')
psi = [ALA2N, ALA2CA, ALA2C, TYR3N]

psi_angle = sum([u.select_atoms(atom) for atom in psi])  # sum of Atoms creates an AtomGroup
psi_angle = psi_angle.dihedral  # convert AtomGroup to Dihedral object

psi_list = []
for ts in u.trajectory:
    psi_list.append(psi_angle.value())
    
    
import matplotlib
import numpy as np
import matplotlib.pyplot as plt


psi_list = np.array(psi_list)

num_bins = 50

fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(psi_list, num_bins, density=True,color = "salmon")



#ax.plot(bins, y, '--')
ax.set_xlabel('Dihedral angle in deg',fontsize=18)
ax.set_ylabel('Frequency density',fontsize=18)
ax.set_title('DFG histogram',fontsize=18)
plt.xlim((-180,180))
plt.xticks(fontsize= 14)
#plt.yticks(fontsize= 20)
# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.savefig('DFG_z6.png', bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
# %matplotlib inline
import numpy as np
import time
import MDAnalysis as mda
from MDAnalysis.tests.datafiles import XTC, GRO
import MDAnalysis.analysis.rms
from MDAnalysis.analysis.rms import rmsd
from MDAnalysis.analysis import align
from MDAnalysis.analysis.dihedrals import Dihedral as dihedral
var_xtc = '/Volumes/3KSPAT/from_2KSPAT/metad_convergence/wt/free_ener_wt/8us/zone7.xtc'
var_gro = '/Volumes/3KSPAT/from_2KSPAT/metad_convergence/wt/free_ener_wt/8us/active_mek_wt_protein.gro' 
u = mda.Universe(var_gro, var_xtc)

selection = 'resname {} and resid {} and name {}'
ALA2N = selection.format('ASP', 208, 'CA')
ALA2CA = selection.format('ASP', 208, 'CG')
ALA2C = selection.format('CYS', 207, 'CA')
TYR3N = selection.format('CYS', 207, 'CB')
psi = [ALA2N, ALA2CA, ALA2C, TYR3N]

psi_angle = sum([u.select_atoms(atom) for atom in psi])  # sum of Atoms creates an AtomGroup
psi_angle = psi_angle.dihedral  # convert AtomGroup to Dihedral object

psi_list = []
for ts in u.trajectory:
    psi_list.append(psi_angle.value())
    
    
import matplotlib
import numpy as np
import matplotlib.pyplot as plt


psi_list = np.array(psi_list)

num_bins = 50

fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(psi_list, num_bins, density=True,color = "salmon")



#ax.plot(bins, y, '--')
ax.set_xlabel('Dihedral angle in deg',fontsize=18)
ax.set_ylabel('Frequency density',fontsize=18)
ax.set_title('DFG histogram',fontsize=18)
plt.xlim((-180,180))
plt.xticks(fontsize= 14)
#plt.yticks(fontsize= 20)
# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.savefig('DFG_z7.png', bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
# %matplotlib inline
import numpy as np
import time
import MDAnalysis as mda
from MDAnalysis.tests.datafiles import XTC, GRO
import MDAnalysis.analysis.rms
from MDAnalysis.analysis.rms import rmsd
from MDAnalysis.analysis import align
from MDAnalysis.analysis.dihedrals import Dihedral as dihedral
var_xtc = '/Volumes/3KSPAT/from_2KSPAT/metad_convergence/wt/free_ener_wt/8us/zone8.xtc'
var_gro = '/Volumes/3KSPAT/from_2KSPAT/metad_convergence/wt/free_ener_wt/8us/active_mek_wt_protein.gro' 
u = mda.Universe(var_gro, var_xtc)

selection = 'resname {} and resid {} and name {}'
ALA2N = selection.format('ASP', 208, 'CA')
ALA2CA = selection.format('ASP', 208, 'CG')
ALA2C = selection.format('CYS', 207, 'CA')
TYR3N = selection.format('CYS', 207, 'CB')
psi = [ALA2N, ALA2CA, ALA2C, TYR3N]

psi_angle = sum([u.select_atoms(atom) for atom in psi])  # sum of Atoms creates an AtomGroup
psi_angle = psi_angle.dihedral  # convert AtomGroup to Dihedral object

psi_list = []
for ts in u.trajectory:
    psi_list.append(psi_angle.value())
    
    
import matplotlib
import numpy as np
import matplotlib.pyplot as plt


psi_list = np.array(psi_list)

num_bins = 50

fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(psi_list, num_bins, density=True,color = "salmon")



#ax.plot(bins, y, '--')
ax.set_xlabel('Dihedral angle in deg',fontsize=18)
ax.set_ylabel('Frequency density',fontsize=18)
ax.set_title('DFG histogram',fontsize=18)
plt.xlim((-180,180))
plt.xticks(fontsize= 14)
#plt.yticks(fontsize= 20)
# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.savefig('DFG_z8.png', bbox_inches = 'tight', dpi = 300)
plt.show()
